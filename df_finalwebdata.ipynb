# %%
import pandas as pd
import numpy as np

# %%
path = "/Users/laurasuemitsu/Desktop/DATA_FT_May_2025/Week 5/Project/df_final_web_data_merged.csv"

df_webdata_final = pd.read_csv(path)

# %%
df_webdata_final.shape

df_webdata_final.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
path_2 = "/Users/laurasuemitsu/Desktop/DATA_FT_May_2025/Week 5/Project/df_final_experiment_clients.csv"

df_experim = pd.read_csv(path_2)

df_experim.drop(columns=("Unnamed: 0"), inplace=True)

# %%
df_experim.head()
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %%
df_merged = df_webdata_final.merge(df_experim, how="left", on="client_id")
df_merged.dropna(inplace=True)
df_merged.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time Variation
# 0  2017-04-17 15:27:07      Test
# 1  2017-04-17 15:26:51      Test
# 2  2017-04-17 15:19:22      Test
# 3  2017-04-17 15:19:13      Test
# 4  2017-04-17 15:18:04      Test

# %%
df_merged["Variation"].unique()
# Out:
# array(['Test', 'Control'], dtype=object)

# %%
df_merged["process_step"] = df_merged["process_step"].replace({"start": 1, "step_1": 2, "step_2": 3, "step_3": 4, "confirm": 5})
# Out:
# /var/folders/jg/t26g89ps577czgvtb19293f00000gn/T/ipykernel_6030/3508836499.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_merged["process_step"] = df_merged["process_step"].replace({"start": 1, "step_1": 2, "step_2": 3, "step_3": 4, "confirm": 5})

# %%
df_merged = df_merged.sort_values(by=["date_time", "visit_id"])

# %%
df_merged.head(20)
# Out:
#         client_id             visitor_id                      visit_id  \
# 35293     7179755  167765295_97487764427   264484508_5982901710_928530
# 35292     7179755  167765295_97487764427   264484508_5982901710_928530
# 35291     7179755  167765295_97487764427   264484508_5982901710_928530
# 35290     7179755  167765295_97487764427   264484508_5982901710_928530
# 35289     7179755  167765295_97487764427   264484508_5982901710_928530
# 79556     4192640  692067844_75217592829   706721307_85347845958_18583
# 79555     4192640  692067844_75217592829   706721307_85347845958_18583
# 79554     4192640  692067844_75217592829   706721307_85347845958_18583
# 79553     4192640  692067844_75217592829   706721307_85347845958_18583
# 79552     4192640  692067844_75217592829   706721307_85347845958_18583
# 104942    6752370  258848572_66112715827  147442660_10728929690_338280
# 104941    6752370  258848572_66112715827  147442660_10728929690_338280
# 104940    6752370  258848572_66112715827  147442660_10728929690_338280
# 104939    6752370  258848572_66112715827  147442660_10728929690_338280
# 104938    6752370  258848572_66112715827  147442660_10728929690_338280
# 104937    6752370  258848572_66112715827  147442660_10728929690_338280
# 104936    6752370  258848572_66112715827  147442660_10728929690_338280
# 104935    6752370  258848572_66112715827  147442660_10728929690_338280
# 104934    6752370  258848572_66112715827  147442660_10728929690_338280
# 104933    6752370  258848572_66112715827  147442660_10728929690_338280
#
#         process_step            date_time Variation
# 35293              1  2017-03-15 00:19:28   Control
# 35292              2  2017-03-15 00:20:50   Control
# 35291              3  2017-03-15 00:22:52   Control
# 35290              4  2017-03-15 00:23:47   Control
# 35289              5  2017-03-15 00:26:24   Control
# 79556              1  2017-03-15 00:43:23      Test
# 79555              2  2017-03-15 00:43:32      Test
# 79554              3  2017-03-15 00:43:48      Test
# 79553              2  2017-03-15 00:44:36      Test
# 79552              1  2017-03-15 00:44:38      Test
# 104942             1  2017-03-15 05:37:35      Test
# 104941             2  2017-03-15 05:37:45      Test
# 104940             2  2017-03-15 05:39:53      Test
# 104939             3  2017-03-15 05:40:01      Test
# 104938             2  2017-03-15 05:40:22      Test
# 104937             1  2017-03-15 05:40:25      Test
# 104936             1  2017-03-15 05:41:38      Test
# 104935             1  2017-03-15 05:42:42      Test
# 104934             1  2017-03-15 05:42:59      Test
# 104933             1  2017-03-15 05:43:08      Test

# %%
df_diff = df_merged.groupby("visit_id").agg({"process_step":"diff"})

# %%
df_diff.value_counts()
# Out:
# process_step
#  1.0            188082
#  0.0             36717
# -1.0             18253
# -2.0              3460
# -3.0              3449
# -4.0               927
#  2.0               628
#  3.0               549
#  4.0                39
# Name: count, dtype: int64

# %%
df_diff.dropna(inplace=True)

# %%
df_diff.value_counts()
# Out:
# process_step
#  1.0            188082
#  0.0             36717
# -1.0             18253
# -2.0              3460
# -3.0              3449
# -4.0               927
#  2.0               628
#  3.0               549
#  4.0                39
# Name: count, dtype: int64

# %%
def error_steps(df):
    list_steps = []

    for i in range(len(df["process_step"]) - 1):
        
        if df["process_step"].iloc[i+1] < df["process_step"].iloc[i]:
            list_steps.append(df["process_step"].iloc[i])
    return list_steps

# %%
from collections import Counter

# %%
# Out:
# Counter({5: 35956, 4: 30053, 3: 27411, 2: 19613})
